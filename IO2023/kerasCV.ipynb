# %% [markdown]
# <a href="https://colab.research.google.com/github/santoshrsarangi/tensorflow/blob/main/IO2023/kerasCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade keras-cv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.6/721.6 kB 13.2 MB/s eta 0:00:00
# ...

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
from keras_cv.models import (
    StableDiffusion,
)

model = StableDiffusion(
    img_width=512,
    img_height=512,
)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = model.text_to_image(
    "cute magical flying dog, fantasy art, "
    "purple color, high quality, highly detailed, elegant, sharp focus, "
    "concept art, character concepts, digital painting, mystery, adventure",
    batch_size=3,
)
# Out:
# 50/50 [==============================] - 119s 2s/step

# %%
def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)

# %%
plot_images(images)
